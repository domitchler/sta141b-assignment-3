# %% [markdown]
# <strong style="color:#F00">Rubric Grade</strong>
#
# Category | Score
# -------- | -----
# R1 | 16
# R2 | 16
# F1 | 16
# F2 | 18
# C1 | 18
# C2 | 18
#
# Notes:
# - No analysis of results
# - figure is not clear enough
# - code could be more efficient and concise

# %% [markdown]
# # STA 141B Assignment 3
#
# Due __Feb 11, 2019__ by 11:59pm. Submit by editing this file, committing the changes with git, and then pushing to your private GitHub repo for the assignment. This assignment will be graded according to the class rubric.
#
# Please do not rename this file or delete the exercise cells, because it will interfere with our grading tools. Put your answers in new cells after each exercise. You can make as many new cells as you like. Use code cells for code and Markdown cells for text. Answer all questions with complete sentences.
#
# The purpose of this assignment is to practice using web APIs and combining data from multiple sources.

# %% [markdown]
# ## USDA Food Composition
#
# The US Department of Agriculture publishes price estimates for fruits and vegetables [online](https://www.ers.usda.gov/data-products/fruit-and-vegetable-prices/fruit-and-vegetable-prices/). The most recent estimates are based on a 2013 survey of US retail stores. We've cleaned and merged the fruit and vegetable price estimates for you. The result is the `fresh.csv` file included in the repository.
#
# In this assignment, you'll combine the price estimates with nutrition data from the [USDA Food Composition Databases](https://ndb.nal.usda.gov/ndb/search/list), and then analyze the resulting dataset.
#
# The USDA Food Composition Databases have a [documented](https://ndb.nal.usda.gov/ndb/doc/index) web API that returns data in JSON format . You need a key in order to use the API. Only 1000 requests are allowed per hour, so it's a good idea to use caching.
#
# [Sign up for an API key here](https://api.data.gov/signup/). The key will work with any data.gov API. You may need the key again later in the quarter, so make sure you save it.

# %% [markdown]
# __Exercise 1.1__
#
# Read the [search request documentation](https://ndb.nal.usda.gov/ndb/doc/apilist/API-SEARCH.md), then write a function called `ndb_search()` that makes a search request. The function should accept the search term as an argument. The function should return the search result items as a list (for 0 items, return an empty list).
#
# Note that the search url is: `https://api.nal.usda.gov/ndb/search`
#
# As an example, a search for `"quail eggs"` might return this list:
#
# ```python
# [{'offset': 0,
#   'group': 'Branded Food Products Database',
#   'name': 'EL COMPI, QUAIL EGGS, UPC: 854955002226',
#   'ndbno': '45362205',
#   'ds': 'LI',
#   'manu': "milly's desserts llc"},
#  {'offset': 1,
#   'group': 'Branded Food Products Database',
#   'name': 'BUDDHA, QUAIL EGGS IN BRINE, UPC: 761934535098',
#   'ndbno': '45099560',
#   'ds': 'LI',
#   'manu': 'Sung Ly International Corporation'},
#  {'offset': 2,
#   'group': 'Branded Food Products Database',
#   'name': 'GRAN SABANA, QUAIL EGGS, UPC: 819140010103',
#   'ndbno': '45169279',
#   'ds': 'LI',
#   'manu': 'L & M C Farms, Inc.'},
#  {'offset': 3,
#   'group': 'Branded Food Products Database',
#   'name': 'L&W, QUAIL EGGS, UPC: 024072000256',
#   'ndbno': '45094890',
#   'ds': 'LI',
#   'manu': 'L&W International Co.'},
#  {'offset': 4,
#   'group': 'Branded Food Products Database',
#   'name': 'CHAOKOH, QUAIL EGG IN BRINE, UPC: 044738074186',
#   'ndbno': '45094707',
#   'ds': 'LI',
#   'manu': 'Theppadung Porn Coconut Co'},
#  {'offset': 5,
#   'group': 'Dairy and Egg Products',
#   'name': 'Egg, quail, whole, fresh, raw',
#   'ndbno': '01140',
#   'ds': 'SR',
#   'manu': 'none'}]
# ```
#
# As usual, make sure you document and test your function.

# %%
import requests
import requests_cache
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import time

requests_cache.install_cache("mycache")

# %%
def read_key(keyfile):
    with open(keyfile) as f:
        return f.readline().strip("\n")

# %%
key = read_key("C:/Users/dthed/Downloads/Keys/data_gov.txt")

# %%
def ndb_search(query):
    """
    Searches for 'query' in the USDA's Food Composition Database. An API key is required to
    use the API. Returns a list of entries that match 'query', or an empty list if no
    matches are found.
    """
    response = requests.get("https://api.nal.usda.gov/ndb/search", params = {
        "api_key": key,
        "q": query
    })

    response.raise_for_status()
    response = response.json()
    if "errors" in response:
        return []
    else:
        return response["list"]["item"]

# %%
ndb_search("quail eggs")
# Out:
# [{'offset': 0,
#   'group': 'Branded Food Products Database',
#   'name': 'EL COMPI, QUAIL EGGS, UPC: 854955002226',
#   'ndbno': '45362205',
#   'ds': 'LI',
#   'manu': "milly's desserts llc"},
#  {'offset': 1,
#   'group': 'Branded Food Products Database',
#   'name': 'BUDDHA, QUAIL EGGS IN BRINE, UPC: 761934535098',
#   'ndbno': '45099560',
#   'ds': 'LI',
#   'manu': 'Sung Ly International Corporation'},
#  {'offset': 2,
#   'group': 'Branded Food Products Database',
#   'name': 'GRAN SABANA, QUAIL EGGS, UPC: 819140010103',
#   'ndbno': '45169279',
#   'ds': 'LI',
#   'manu': 'L & M C Farms, Inc.'},
#  {'offset': 3,
#   'group': 'Branded Food Products Database',
#   'name': 'L&W, QUAIL EGGS, UPC: 024072000256',
#   'ndbno': '45094890',
#   'ds': 'LI',
#   'manu': 'L&W International Co.'},
#  {'offset': 4,
#   'group': 'Branded Food Products Database',
#   'name': 'CHAOKOH, QUAIL EGG IN BRINE, UPC: 044738074186',
#   'ndbno': '45094707',
#   'ds': 'LI',
#   'manu': 'Theppadung Porn Coconut Co'},
#  {'offset': 5,
#   'group': 'Dairy and Egg Products',
#   'name': 'Egg, quail, whole, fresh, raw',
#   'ndbno': '01140',
#   'ds': 'SR',
#   'manu': 'none'}]

# %%
ndb_search("fdsklfds")
# Out:
# []

# %% [markdown]
# __Exercise 1.2__
#
# Use your search function to get NDB numbers for the foods in the `fresh.csv` file. It's okay if you don't get an NDB number for every food, but try to come up with a strategy that gets most of them. Discuss your strategy in a short paragraph.
#
# Hints:
#
# * The foods are all raw and unbranded.
# * You can test search terms with the [online search page](https://ndb.nal.usda.gov/ndb/search/list).
# * The [Python](https://docs.python.org/3/library/stdtypes.html#string-methods) and [Pandas](http://pandas.pydata.org/pandas-docs/stable/user_guide/text.html) string methods are useful here. It's okay if you use _simple_ regular expressions in the Pandas methods, although this exercise can be solved without them.
# * You can merge data frames that have a column in common with `pd.merge()`.

# %%
fresh_complete = pd.read_csv("fresh.csv")

fresh_complete
# Out:
#                           form  price_per_lb     yield  lb_per_cup  \
# 0                       Fresh1      0.316639  0.520000    0.330693
# 1                       Fresh1      0.520794  0.510000    0.374786
# 2                       Fresh1      1.480396  0.740000    0.407855
# 3                       Fresh1      2.508450  0.940000    0.319670
# 4                       Fresh1      1.987999  0.940000    0.363763
# 5                       Fresh1      1.097122  0.680000    0.407855
# 6                       Fresh1      6.877702  0.960000    0.319670
# 7                       Fresh1      2.078430  0.560000    0.341717
# 8                       Fresh1      0.652795  0.510000    0.363763
# 9                       Fresh1      3.087138  0.930000    0.363763
# 10                      Fresh1      0.825991  0.460000    0.374786
# 11                      Fresh1      1.293532  0.620000    0.308647
# 12                      Fresh1      2.181328  0.760000    0.385809
# 13                      Fresh1      3.213068  0.920000    0.341717
# 14                      Fresh1      0.549417  0.640000    0.330693
# 15                      Fresh1      1.615534  0.900000    0.242508
# 16                      Fresh1      1.677932  0.960000    0.341717
# 17                      Fresh1      1.881247  0.910000    0.319670
# 18                      Fresh1      1.517592  0.900000    0.363763
# 19                      Fresh1      1.009797  0.490000    0.462971
# 20                     Fresh1       5.661671  0.960000    0.319670
# 21                      Fresh1      2.235873  0.960000    0.330693
# 22                      Fresh1      4.391108  0.950000    0.319670
# 23                      Fresh1      1.323517  0.710000    0.363763
# 24                      Fresh1      3.075611  0.493835    0.396832
# 25  Fresh, consumed with peel1      1.255586  0.970000    0.264555
# 26              Fresh, peeled1      1.255586  0.730000    0.264555
# 27                      Fresh1      1.089256  0.950000    0.242508
# 28                      Fresh1      1.047382  0.900000    0.352740
# 29                      Fresh1      2.508413  0.750000    0.319670
# 30                      Fresh1      2.679269  0.840000    0.308647
# 31                      Fresh1      0.603736  0.811301    0.264555
# 32                      Fresh1      2.629468  1.160000    0.286601
# 33                      Fresh1      2.126276  0.846575    0.275578
# 34                      Fresh1      1.119309  0.458554    0.451948
# 35                      Fresh1      2.320671  0.820000    0.264555
# 36        Fresh green cabbage1      0.623871  0.778797    0.330693
# 37          Fresh red cabbage1      1.024125  0.779107    0.330693
# 38                      Fresh1      1.054409  0.811301    0.440925
# 39                      Fresh1      1.640046  0.769500    0.396832
# 40                      Fresh1      1.462104  0.900000    0.275578
# 41                      Fresh1      1.292011  0.714000    0.451948
# 42                      Fresh1      2.225544  0.740753    0.319670
# 43                      Fresh1      2.877290  1.050000    0.286601
# 44                      Fresh1      2.363733  0.375309    0.385809
# 45                      Fresh1      3.820824  0.769474    0.352740
# 46                      Fresh1      1.494971  0.820000    0.264555
# 47                      Fresh1      2.962093  1.060000    0.341717
# 48                      Fresh1      3.264928  0.540000    0.363763
#
#     price_per_cup              food        type
# 0        0.201366        watermelon       fruit
# 1        0.382718        cantaloupe       fruit
# 2        0.815929        tangerines       fruit
# 3        0.853060      strawberries       fruit
# 4        0.769319             plums       fruit
# 5        0.658039           oranges       fruit
# 6        2.290205       raspberries       fruit
# 7        1.268275       pomegranate       fruit
# 8        0.465612         pineapple       fruit
# 9        1.207511          apricots       fruit
# 10       0.672978          honeydew       fruit
# 11       0.643943            papaya       fruit
# 12       1.107337              kiwi       fruit
# 13       1.193433          cherries       fruit
# 14       0.283889           bananas       fruit
# 15       0.435312            apples       fruit
# 16       0.597268           peaches       fruit
# 17       0.660856        nectarines       fruit
# 18       0.613382             pears       fruit
# 19       0.954095        grapefruit       fruit
# 20       1.885279      blackberries       fruit
# 21       0.770196            grapes       fruit
# 22       1.477586       blueberries       fruit
# 23       0.678093           mangoes       fruit
# 24       2.471473         asparagus  vegetables
# 25       0.342444         cucumbers  vegetables
# 26       0.455029         cucumbers  vegetables
# 27       0.278057   lettuce_iceberg  vegetables
# 28       0.410503            onions  vegetables
# 29       1.069153     turnip_greens  vegetables
# 30       0.984463    mustard_greens  vegetables
# 31       0.196870          potatoes  vegetables
# 32       0.649662    collard_greens  vegetables
# 33       0.692147       green_beans  vegetables
# 34       1.103183      acorn_squash  vegetables
# 35       0.748713       red_peppers  vegetables
# 36       0.264909           cabbage  vegetables
# 37       0.434692           cabbage  vegetables
# 38       0.573049    sweet_potatoes  vegetables
# 39       0.845773     summer_squash  vegetables
# 40       0.447693            radish  vegetables
# 41       0.817817  butternut_squash  vegetables
# 42       0.960428          avocados  vegetables
# 43       0.785366              kale  vegetables
# 44       2.429865         artichoke  vegetables
# 45       1.751530              okra  vegetables
# 46       0.482319     green_peppers  vegetables
# 47       0.954902  brussels_sprouts  vegetables
# 48       2.199369        corn_sweet  vegetables

# %%
def narrow_search(food, form, kind, source = 'SR', manu = 'none', exclude = ''):
    """
    Helper function for Exercise 1.2. Returns a pandas DataFrame of results from a ndb_search
    with more specific parameters to identify the desired NDB Numbers for each raw food.
    
    Inputs: food name, form (e.g., peeled or with peel), kind (e.g., fruit or veggie), data
            source (defaults to Standard Reference -- 'SR'), manufacturer (defaults to 'none'),
            search terms to exclude (defaults to nothing, can be a string or a regex).
    """
    search_term = "raw " + food + " " + form # all desired foods are raw
    
    result = ndb_search(search_term)
    
    # Certain fruits (i.e., kiwi) are not found unless we add the word "fruit" to the food name
    if not result and kind == 'fruit':
        result = ndb_search("raw " + food + kind + " " + form)
    
    result_df = pd.DataFrame(result)
    
    crit1 = result_df["ds"] == source # filter results by database
    crit2 = result_df["manu"] == manu # filter results by manufacturer
    crit3 = result_df["group"] == "Fruits and Fruit Juices" # filter results to only include fruits
    
    # If the food is a fruit, filter by above criteria. Otherwise, add veggies to the filter.
    # Certain foods that are labeled as vegetables (e.g., avocados) have seeds and are
    # therefore considered fruits in the USDA Food Database.
    if kind == "fruit":
        all_crit = crit1 & crit2 & crit3
    else:
        crit4 = result_df["group"] == "Vegetables and Vegetable Products"
        all_crit = crit1 & crit2 & (crit3 | crit4)
    
    # filter results to exclude specified terms
    if exclude:
        crit5 = ~result_df["name"].str.contains(exclude, case = False)
        all_crit = all_crit & crit5
    
    # Apply the filter criteria to limit undesired results
    result_df = result_df[all_crit]
    
    return result_df

# %%
fresh = fresh_complete[["form", "food", "type"]] # Extract only the necessary columns from fresh_complete
ndbno = [] # store the NDBNO's in a list

for x in range(len(fresh)):
    row = fresh.iloc[x,:] # deal with one row at a time
    
    food = row["food"].replace("_", " ") # replace underscores with spaces in food names
    
    # Remove '1' from end of form, 'Fresh' from beginning of form, delete some unnecessary words
    form = row["form"].rstrip('1').lstrip("Fresh,").replace("consumed", "").replace("cabbage", "").strip()
    kind = row["type"]
    
    # Perform search, excluding results that contain hyphens, 'juice', 'acerola', 'muscadine', or 'scallop'.
    results = narrow_search(food, form, kind, exclude = "juice|-|acerola|muscadine|scallop")
    
    if results.empty:
        # NO RESULTS:
        nbdno.append("*****")
    else:
        # Add each NDBNO to list (preserving order)
        ndbno.append(results.iloc[0,:]["ndbno"])

    time.sleep(0.1)

# print(ndbno)

# %%
fresh_complete["ndbno"] = ndbno # add the NDBNO's as a new column in the fresh_complete DataFrame

fresh_complete
# Out:
#                           form  price_per_lb     yield  lb_per_cup  \
# 0                       Fresh1      0.316639  0.520000    0.330693
# 1                       Fresh1      0.520794  0.510000    0.374786
# 2                       Fresh1      1.480396  0.740000    0.407855
# 3                       Fresh1      2.508450  0.940000    0.319670
# 4                       Fresh1      1.987999  0.940000    0.363763
# 5                       Fresh1      1.097122  0.680000    0.407855
# 6                       Fresh1      6.877702  0.960000    0.319670
# 7                       Fresh1      2.078430  0.560000    0.341717
# 8                       Fresh1      0.652795  0.510000    0.363763
# 9                       Fresh1      3.087138  0.930000    0.363763
# 10                      Fresh1      0.825991  0.460000    0.374786
# 11                      Fresh1      1.293532  0.620000    0.308647
# 12                      Fresh1      2.181328  0.760000    0.385809
# 13                      Fresh1      3.213068  0.920000    0.341717
# 14                      Fresh1      0.549417  0.640000    0.330693
# 15                      Fresh1      1.615534  0.900000    0.242508
# 16                      Fresh1      1.677932  0.960000    0.341717
# 17                      Fresh1      1.881247  0.910000    0.319670
# 18                      Fresh1      1.517592  0.900000    0.363763
# 19                      Fresh1      1.009797  0.490000    0.462971
# 20                     Fresh1       5.661671  0.960000    0.319670
# 21                      Fresh1      2.235873  0.960000    0.330693
# 22                      Fresh1      4.391108  0.950000    0.319670
# 23                      Fresh1      1.323517  0.710000    0.363763
# 24                      Fresh1      3.075611  0.493835    0.396832
# 25  Fresh, consumed with peel1      1.255586  0.970000    0.264555
# 26              Fresh, peeled1      1.255586  0.730000    0.264555
# 27                      Fresh1      1.089256  0.950000    0.242508
# 28                      Fresh1      1.047382  0.900000    0.352740
# 29                      Fresh1      2.508413  0.750000    0.319670
# 30                      Fresh1      2.679269  0.840000    0.308647
# 31                      Fresh1      0.603736  0.811301    0.264555
# 32                      Fresh1      2.629468  1.160000    0.286601
# 33                      Fresh1      2.126276  0.846575    0.275578
# 34                      Fresh1      1.119309  0.458554    0.451948
# 35                      Fresh1      2.320671  0.820000    0.264555
# 36        Fresh green cabbage1      0.623871  0.778797    0.330693
# 37          Fresh red cabbage1      1.024125  0.779107    0.330693
# 38                      Fresh1      1.054409  0.811301    0.440925
# 39                      Fresh1      1.640046  0.769500    0.396832
# 40                      Fresh1      1.462104  0.900000    0.275578
# 41                      Fresh1      1.292011  0.714000    0.451948
# 42                      Fresh1      2.225544  0.740753    0.319670
# 43                      Fresh1      2.877290  1.050000    0.286601
# 44                      Fresh1      2.363733  0.375309    0.385809
# 45                      Fresh1      3.820824  0.769474    0.352740
# 46                      Fresh1      1.494971  0.820000    0.264555
# 47                      Fresh1      2.962093  1.060000    0.341717
# 48                      Fresh1      3.264928  0.540000    0.363763
#
#     price_per_cup              food        type  ndbno
# 0        0.201366        watermelon       fruit  09326
# 1        0.382718        cantaloupe       fruit  09181
# 2        0.815929        tangerines       fruit  09218
# 3        0.853060      strawberries       fruit  09316
# 4        0.769319             plums       fruit  09279
# 5        0.658039           oranges       fruit  09201
# 6        2.290205       raspberries       fruit  09302
# 7        1.268275       pomegranate       fruit  09286
# 8        0.465612         pineapple       fruit  09266
# 9        1.207511          apricots       fruit  09021
# 10       0.672978          honeydew       fruit  09184
# 11       0.643943            papaya       fruit  09226
# 12       1.107337              kiwi       fruit  09148
# 13       1.193433          cherries       fruit  09070
# 14       0.283889           bananas       fruit  09040
# 15       0.435312            apples       fruit  09003
# 16       0.597268           peaches       fruit  09236
# 17       0.660856        nectarines       fruit  09191
# 18       0.613382             pears       fruit  09252
# 19       0.954095        grapefruit       fruit  09117
# 20       1.885279      blackberries       fruit  09042
# 21       0.770196            grapes       fruit  09131
# 22       1.477586       blueberries       fruit  09050
# 23       0.678093           mangoes       fruit  09176
# 24       2.471473         asparagus  vegetables  11011
# 25       0.342444         cucumbers  vegetables  11205
# 26       0.455029         cucumbers  vegetables  11206
# 27       0.278057   lettuce_iceberg  vegetables  11252
# 28       0.410503            onions  vegetables  11282
# 29       1.069153     turnip_greens  vegetables  11568
# 30       0.984463    mustard_greens  vegetables  11270
# 31       0.196870          potatoes  vegetables  11362
# 32       0.649662    collard_greens  vegetables  11161
# 33       0.692147       green_beans  vegetables  11052
# 34       1.103183      acorn_squash  vegetables  11482
# 35       0.748713       red_peppers  vegetables  11821
# 36       0.264909           cabbage  vegetables  11109
# 37       0.434692           cabbage  vegetables  11112
# 38       0.573049    sweet_potatoes  vegetables  11507
# 39       0.845773     summer_squash  vegetables  11641
# 40       0.447693            radish  vegetables  11429
# 41       0.817817  butternut_squash  vegetables  11485
# 42       0.960428          avocados  vegetables  09038
# 43       0.785366              kale  vegetables  11233
# 44       2.429865         artichoke  vegetables  11007
# 45       1.751530              okra  vegetables  11278
# 46       0.482319     green_peppers  vegetables  11333
# 47       0.954902  brussels_sprouts  vegetables  11098
# 48       2.199369        corn_sweet  vegetables  11900

# %% [markdown]
# __Exercise 1.3__
#
# Read the [food reports V2 documentation](https://ndb.nal.usda.gov/ndb/doc/apilist/API-FOOD-REPORTV2.md), then write a function called `ndb_report()` that requests a _basic_ food report. The function should accept the NDB number as an argument and return the list of nutrients for the food.
#
# Note that the report url is: `https://api.nal.usda.gov/ndb/V2/reports`
#
# For example, for `"09279"` (raw plums) the first element of the returned list should be:
#
# ```python
# {'nutrient_id': '255',
#  'name': 'Water',
#  'derivation': 'NONE',
#  'group': 'Proximates',
#  'unit': 'g',
#  'value': '87.23',
#  'measures': [{'label': 'cup, sliced',
#    'eqv': 165.0,
#    'eunit': 'g',
#    'qty': 1.0,
#    'value': '143.93'},
#   {'label': 'fruit (2-1/8" dia)',
#    'eqv': 66.0,
#    'eunit': 'g',
#    'qty': 1.0,
#    'value': '57.57'},
#   {'label': 'NLEA serving',
#    'eqv': 151.0,
#    'eunit': 'g',
#    'qty': 1.0,
#    'value': '131.72'}]}
# ```
#
# Be sure to document and test your function.

# %%
def ndb_report(ndbno):
    response = requests.get("https://api.nal.usda.gov/ndb/V2/reports", params = {
        "api_key": key,
        "ndbno": [ndbno]
    })

    response.raise_for_status()
    response = response.json()
    
    if response["notfound"] is not 0:
        print("Food not found in database. Please try again.")
        return []
    else:
        nutrients = response["foods"][0]["food"]["nutrients"]
        return nutrients

# %%
plums = ndb_report("09279")
plums
# Out:
# [{'nutrient_id': '255',
#   'name': 'Water',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '87.23',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '143.93'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '57.57'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '131.72'}]},
#  {'nutrient_id': '208',
#   'name': 'Energy',
#   'derivation': 'NC',
#   'group': 'Proximates',
#   'unit': 'kcal',
#   'value': '46',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '76'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '30'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '69'}]},
#  {'nutrient_id': '203',
#   'name': 'Protein',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '0.70',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '1.15'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.46'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '1.06'}]},
#  {'nutrient_id': '204',
#   'name': 'Total lipid (fat)',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '0.28',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.46'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.18'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.42'}]},
#  {'nutrient_id': '205',
#   'name': 'Carbohydrate, by difference',
#   'derivation': 'NC',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '11.42',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '18.84'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '7.54'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '17.24'}]},
#  {'nutrient_id': '291',
#   'name': 'Fiber, total dietary',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '1.4',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '2.3'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.9'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '2.1'}]},
#  {'nutrient_id': '269',
#   'name': 'Sugars, total',
#   'derivation': 'NONE',
#   'group': 'Proximates',
#   'unit': 'g',
#   'value': '9.92',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '16.37'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '6.55'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '14.98'}]},
#  {'nutrient_id': '301',
#   'name': 'Calcium, Ca',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '6',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '10'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '4'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '9'}]},
#  {'nutrient_id': '303',
#   'name': 'Iron, Fe',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '0.17',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.28'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.11'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.26'}]},
#  {'nutrient_id': '304',
#   'name': 'Magnesium, Mg',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '7',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '12'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '5'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '11'}]},
#  {'nutrient_id': '305',
#   'name': 'Phosphorus, P',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '16',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '26'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '11'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '24'}]},
#  {'nutrient_id': '306',
#   'name': 'Potassium, K',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '157',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '259'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '104'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '237'}]},
#  {'nutrient_id': '307',
#   'name': 'Sodium, Na',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '0',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'}]},
#  {'nutrient_id': '309',
#   'name': 'Zinc, Zn',
#   'derivation': 'NONE',
#   'group': 'Minerals',
#   'unit': 'mg',
#   'value': '0.10',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.17'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.07'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.15'}]},
#  {'nutrient_id': '401',
#   'name': 'Vitamin C, total ascorbic acid',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '9.5',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '15.7'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '6.3'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '14.3'}]},
#  {'nutrient_id': '404',
#   'name': 'Thiamin',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '0.028',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.046'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.018'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.042'}]},
#  {'nutrient_id': '405',
#   'name': 'Riboflavin',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '0.026',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.043'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.017'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.039'}]},
#  {'nutrient_id': '406',
#   'name': 'Niacin',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '0.417',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.688'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.275'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.630'}]},
#  {'nutrient_id': '415',
#   'name': 'Vitamin B-6',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '0.029',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.048'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.019'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.044'}]},
#  {'nutrient_id': '435',
#   'name': 'Folate, DFE',
#   'derivation': 'NC',
#   'group': 'Vitamins',
#   'unit': 'µg',
#   'value': '5',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '8'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '3'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '8'}]},
#  {'nutrient_id': '418',
#   'name': 'Vitamin B-12',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'µg',
#   'value': '0.00',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.00'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.00'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.00'}]},
#  {'nutrient_id': '320',
#   'name': 'Vitamin A, RAE',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'µg',
#   'value': '17',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '28'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '11'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '26'}]},
#  {'nutrient_id': '318',
#   'name': 'Vitamin A, IU',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'IU',
#   'value': '345',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '569'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '228'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '521'}]},
#  {'nutrient_id': '323',
#   'name': 'Vitamin E (alpha-tocopherol)',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'mg',
#   'value': '0.26',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.43'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.17'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.39'}]},
#  {'nutrient_id': '328',
#   'name': 'Vitamin D (D2 + D3)',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'µg',
#   'value': '0.0',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.0'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.0'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.0'}]},
#  {'nutrient_id': '324',
#   'name': 'Vitamin D',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'IU',
#   'value': '0',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'}]},
#  {'nutrient_id': '430',
#   'name': 'Vitamin K (phylloquinone)',
#   'derivation': 'NONE',
#   'group': 'Vitamins',
#   'unit': 'µg',
#   'value': '6.4',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '10.6'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '4.2'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '9.7'}]},
#  {'nutrient_id': '606',
#   'name': 'Fatty acids, total saturated',
#   'derivation': 'NC',
#   'group': 'Lipids',
#   'unit': 'g',
#   'value': '0.017',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.028'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.011'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.026'}]},
#  {'nutrient_id': '645',
#   'name': 'Fatty acids, total monounsaturated',
#   'derivation': 'NC',
#   'group': 'Lipids',
#   'unit': 'g',
#   'value': '0.134',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.221'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.088'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.202'}]},
#  {'nutrient_id': '646',
#   'name': 'Fatty acids, total polyunsaturated',
#   'derivation': 'NC',
#   'group': 'Lipids',
#   'unit': 'g',
#   'value': '0.044',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.073'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.029'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.066'}]},
#  {'nutrient_id': '605',
#   'name': 'Fatty acids, total trans',
#   'derivation': 'NONE',
#   'group': 'Lipids',
#   'unit': 'g',
#   'value': '0.000',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.000'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.000'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0.000'}]},
#  {'nutrient_id': '601',
#   'name': 'Cholesterol',
#   'derivation': 'NONE',
#   'group': 'Lipids',
#   'unit': 'mg',
#   'value': '0',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'}]},
#  {'nutrient_id': '262',
#   'name': 'Caffeine',
#   'derivation': 'NONE',
#   'group': 'Other',
#   'unit': 'mg',
#   'value': '0',
#   'measures': [{'label': 'cup, sliced',
#     'eqv': 165.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'fruit (2-1/8" dia)',
#     'eqv': 66.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'},
#    {'label': 'NLEA serving',
#     'eqv': 151.0,
#     'eunit': 'g',
#     'qty': 1.0,
#     'value': '0'}]}]

# %%
ndb_report("5849450")
# Out:
# Food not found in database. Please try again.
# []

# %% [markdown]
# __Exercise 1.4.__
#
# Answer any two of the questions below. For each answer, state the question, write 2-3 paragraphs, and support your conclusions with plots.
#
#  If you like, you can replace one question with a question you came up with on your own.
#
# * Are fruits typically higher in kilocalories, or vegetables?
# * How does yield for fibrous foods (high in dietary fiber) compare to other foods?
# * Which food provides the widest variety of nutrients?
# * Which nutrients are the most expensive?
# * Which foods are the best value for the price? "Best value" might mean highest yield per dollar, most kilocalories per dollar, or some other reasonable definition.
# * How do the price distributions compare for fruits and vegetables?

# %% [markdown]
# __Are fruits typically higher in kilocalories, or vegetables?__
#
# For this question, I chose to examine the nutrient reports for each food and extract the number of kilocalories (per 100g) from the `Energy` nutrient. To assist with this process, I created a helper function `get_kilocals()` that takes a DataFrame of foods as input and returns a list containing the kilocalorie counts for each food in the DataFrame. After running my helper function on `fresh_complete`, I added that list as a new column to the DataFrame.
#
# I created a boxplot and swarmplot using Seaborn to compare the distributions of each food groups' kilocalories. From the boxplots, we can see that fruits are typically higher in kilocalories than vegetables, but there appears to be one vegetable that is much higher in kilocalories than all other foods in our comparison. To figure out which one this is, I sorted the data by kilocalorie counts and extracted the top five highest kilocalorie count foods. Surprisingly, avocados tops the chart at 167 kcals per 100g, which is nearly double the kilocalorie count of any other food. It should also be mentioned that avocados have seeds, so despite being labeled in our given data as a vegetable, the USDA categorizes the avocado as a fruit.
#
# Finally, I examined the mean kilocalorie count for each food group separately so that I could compare them. The mean of the fruit kilocalorie counts was about 51.0, and the mean of the vegetable kilocalorie counts was 39.8. This supports my hypothesis that fruits are typically higher in kilocalories than vegetables.

# %%
def get_kilocals(df):
    kcals = []
    for x in range(len(df)):
        row = df.iloc[x,:] # deal with one row (food) at a time
        
        # get NDBNO from row and access its nutrient report
        report = pd.DataFrame(ndb_report(row["ndbno"]))
        
        # find nutrient with units of kcals and get the amount from 'value' column
        energy = report.loc[report["unit"] == "kcal", "value"]
        
        energy = float(energy) # convert string to numeric value
        
        kcals.append(energy)
    return kcals

# %%
kcals = get_kilocals(fresh_complete)
fresh_complete["kcals"] = kcals

ax = sns.boxplot(x = "type", y = "kcals", data = fresh_complete)
ax = sns.swarmplot(x = "type", y = "kcals", data = fresh_complete, color = ".25")

# %%
# Find foods with highest kcal counts
fresh_complete.sort_values(by = "kcals", ascending = False).head()
# Out:
#       form  price_per_lb     yield  lb_per_cup  price_per_cup            food  \
# 42  Fresh1      2.225544  0.740753    0.319670       0.960428        avocados
# 14  Fresh1      0.549417  0.640000    0.330693       0.283889         bananas
# 38  Fresh1      1.054409  0.811301    0.440925       0.573049  sweet_potatoes
# 48  Fresh1      3.264928  0.540000    0.363763       2.199369      corn_sweet
# 7   Fresh1      2.078430  0.560000    0.341717       1.268275     pomegranate
#
#           type  ndbno  kcals
# 42  vegetables  09038  167.0
# 14       fruit  09040   89.0
# 38  vegetables  11507   86.0
# 48  vegetables  11900   86.0
# 7        fruit  09286   83.0

# %%
# Split the foods into two dataframes based on group and extract kcal values
fruits = fresh_complete.loc[fresh_complete["type"] == "fruit", "kcals"]
veggies = fresh_complete.loc[fresh_complete["type"] == "vegetables", "kcals"]

# Find means of fruit and veggie kcals
print("Mean of fruit kcals:  " + str(sum(fruits)/len(fruits)))
print("Mean of veggie kcals: " + str(sum(veggies)/len(veggies)))
# Out:
# Mean of fruit kcals:  51.041666666666664
# Mean of veggie kcals: 39.8

# %% [markdown]
# __Which foods are the best value for the price?__
#
# For this question I chose to interpret value in terms of kilocalories per dollar, so that best value would mean highest energy yield (kilocalories) per dollar. I noticed that there were two `price` columns in the `fresh_complete` DataFrame: `price_per_lb` and `price_per_cup`. To determine which was most appropriate metric for my purposes, I examined the USDA nutrient report and found that the nutrient values are given in terms of unit per 100g of food. For example, the nutrient report for Watermelon gives Energy in terms of kilocalories per 100g of watermelon. The nutrient report gives energy based on grams (a measurement of mass), so I decided it would be most appropriate to use the `price_per_lb` column for my comparison. Pounds is a measure of weight (which is closely related to mass), whereas cups is a measure of volume.
#
# I created a new column in `fresh_complete` called `value_lb` that contains the kilocalories (per 100g) divided by the price per pound of each food. I then sorted the DataFrame based on this new column in descending order, and picked the 10 best-value foods to compare. Using Seaborn, I created a simple barplot to illustrate the value ratio for each of these foods. As can be seen from the data and the plot, bananas provide the most kilocalories for the price (by far) out of all the foods we examined in this assignment. Bananas provide a value ratio of over 160, whereas potatoes (the next best value food) has a value ratio of about 96. The food with the worst value for the price is asparagus, with a value ratio of about 6.5.

# %%
value_lb = fresh_complete["kcals"] / fresh_complete["price_per_lb"]
fresh_complete["value_lb"] = value_lb

fresh_complete.head()
# Out:
#      form  price_per_lb  yield  lb_per_cup  price_per_cup          food  \
# 0  Fresh1      0.316639   0.52    0.330693       0.201366    watermelon
# 1  Fresh1      0.520794   0.51    0.374786       0.382718    cantaloupe
# 2  Fresh1      1.480396   0.74    0.407855       0.815929    tangerines
# 3  Fresh1      2.508450   0.94    0.319670       0.853060  strawberries
# 4  Fresh1      1.987999   0.94    0.363763       0.769319         plums
#
#     type  ndbno  kcals   value_lb
# 0  fruit  09326   30.0  94.745186
# 1  fruit  09181   34.0  65.284971
# 2  fruit  09218   53.0  35.801227
# 3  fruit  09316   32.0  12.756884
# 4  fruit  09279   46.0  23.138846

# %%
best_value_lb = fresh_complete.sort_values(by = "value_lb", ascending = False)
best_value_lb
# Out:
#                           form  price_per_lb     yield  lb_per_cup  \
# 14                      Fresh1      0.549417  0.640000    0.330693
# 31                      Fresh1      0.603736  0.811301    0.264555
# 0                       Fresh1      0.316639  0.520000    0.330693
# 38                      Fresh1      1.054409  0.811301    0.440925
# 8                       Fresh1      0.652795  0.510000    0.363763
# 42                      Fresh1      2.225544  0.740753    0.319670
# 1                       Fresh1      0.520794  0.510000    0.374786
# 23                      Fresh1      1.323517  0.710000    0.363763
# 5                       Fresh1      1.097122  0.680000    0.407855
# 10                      Fresh1      0.825991  0.460000    0.374786
# 36        Fresh green cabbage1      0.623871  0.778797    0.330693
# 7                       Fresh1      2.078430  0.560000    0.341717
# 28                      Fresh1      1.047382  0.900000    0.352740
# 18                      Fresh1      1.517592  0.900000    0.363763
# 19                      Fresh1      1.009797  0.490000    0.462971
# 2                       Fresh1      1.480396  0.740000    0.407855
# 34                      Fresh1      1.119309  0.458554    0.451948
# 41                      Fresh1      1.292011  0.714000    0.451948
# 11                      Fresh1      1.293532  0.620000    0.308647
# 15                      Fresh1      1.615534  0.900000    0.242508
# 37          Fresh red cabbage1      1.024125  0.779107    0.330693
# 21                      Fresh1      2.235873  0.960000    0.330693
# 12                      Fresh1      2.181328  0.760000    0.385809
# 48                      Fresh1      3.264928  0.540000    0.363763
# 17                      Fresh1      1.881247  0.910000    0.319670
# 16                      Fresh1      1.677932  0.960000    0.341717
# 4                       Fresh1      1.987999  0.940000    0.363763
# 44                      Fresh1      2.363733  0.375309    0.385809
# 13                      Fresh1      3.213068  0.920000    0.341717
# 9                       Fresh1      3.087138  0.930000    0.363763
# 33                      Fresh1      2.126276  0.846575    0.275578
# 47                      Fresh1      2.962093  1.060000    0.341717
# 46                      Fresh1      1.494971  0.820000    0.264555
# 22                      Fresh1      4.391108  0.950000    0.319670
# 27                      Fresh1      1.089256  0.950000    0.242508
# 29                      Fresh1      2.508413  0.750000    0.319670
# 3                       Fresh1      2.508450  0.940000    0.319670
# 32                      Fresh1      2.629468  1.160000    0.286601
# 43                      Fresh1      2.877290  1.050000    0.286601
# 25  Fresh, consumed with peel1      1.255586  0.970000    0.264555
# 35                      Fresh1      2.320671  0.820000    0.264555
# 40                      Fresh1      1.462104  0.900000    0.275578
# 30                      Fresh1      2.679269  0.840000    0.308647
# 39                      Fresh1      1.640046  0.769500    0.396832
# 45                      Fresh1      3.820824  0.769474    0.352740
# 26              Fresh, peeled1      1.255586  0.730000    0.264555
# 20                     Fresh1       5.661671  0.960000    0.319670
# 6                       Fresh1      6.877702  0.960000    0.319670
# 24                      Fresh1      3.075611  0.493835    0.396832
#
#     price_per_cup              food        type  ndbno  kcals    value_lb
# 14       0.283889           bananas       fruit  09040   89.0  161.989805
# 31       0.196870          potatoes  vegetables  11362   58.0   96.068466
# 0        0.201366        watermelon       fruit  09326   30.0   94.745186
# 38       0.573049    sweet_potatoes  vegetables  11507   86.0   81.562252
# 8        0.465612         pineapple       fruit  09266   50.0   76.593777
# 42       0.960428          avocados  vegetables  09038  167.0   75.037831
# 1        0.382718        cantaloupe       fruit  09181   34.0   65.284971
# 23       0.678093           mangoes       fruit  09176   60.0   45.333748
# 5        0.658039           oranges       fruit  09201   49.0   44.662324
# 10       0.672978          honeydew       fruit  09184   36.0   43.583999
# 36       0.264909           cabbage  vegetables  11109   25.0   40.072372
# 7        1.268275       pomegranate       fruit  09286   83.0   39.933988
# 28       0.410503            onions  vegetables  11282   40.0   38.190466
# 18       0.613382             pears       fruit  09252   57.0   37.559502
# 19       0.954095        grapefruit       fruit  09117   37.0   36.641020
# 2        0.815929        tangerines       fruit  09218   53.0   35.801227
# 34       1.103183      acorn_squash  vegetables  11482   40.0   35.736343
# 41       0.817817  butternut_squash  vegetables  11485   45.0   34.829424
# 11       0.643943            papaya       fruit  09226   43.0   33.242322
# 15       0.435312            apples       fruit  09003   52.0   32.187507
# 37       0.434692           cabbage  vegetables  11112   31.0   30.269742
# 21       0.770196            grapes       fruit  09131   67.0   29.965921
# 12       1.107337              kiwi       fruit  09148   61.0   27.964620
# 48       2.199369        corn_sweet  vegetables  11900   86.0   26.340551
# 17       0.660856        nectarines       fruit  09191   44.0   23.388738
# 16       0.597268           peaches       fruit  09236   39.0   23.242902
# 4        0.769319             plums       fruit  09279   46.0   23.138846
# 44       2.429865         artichoke  vegetables  11007   47.0   19.883799
# 13       1.193433          cherries       fruit  09070   63.0   19.607427
# 9        1.207511          apricots       fruit  09021   48.0   15.548383
# 33       0.692147       green_beans  vegetables  11052   31.0   14.579478
# 47       0.954902  brussels_sprouts  vegetables  11098   43.0   14.516762
# 46       0.482319     green_peppers  vegetables  11333   20.0   13.378187
# 22       1.477586       blueberries       fruit  09050   57.0   12.980777
# 27       0.278057   lettuce_iceberg  vegetables  11252   14.0   12.852815
# 29       1.069153     turnip_greens  vegetables  11568   32.0   12.757070
# 3        0.853060      strawberries       fruit  09316   32.0   12.756884
# 32       0.649662    collard_greens  vegetables  11161   32.0   12.169760
# 43       0.785366              kale  vegetables  11233   35.0   12.164223
# 25       0.342444         cucumbers  vegetables  11205   15.0   11.946617
# 35       0.748713       red_peppers  vegetables  11821   26.0   11.203658
# 40       0.447693            radish  vegetables  11429   16.0   10.943131
# 30       0.984463    mustard_greens  vegetables  11270   27.0   10.077377
# 39       0.845773     summer_squash  vegetables  11641   16.0    9.755827
# 45       1.751530              okra  vegetables  11278   33.0    8.636880
# 26       0.455029         cucumbers  vegetables  11206   10.0    7.964411
# 20       1.885279      blackberries       fruit  09042   43.0    7.594930
# 6        2.290205       raspberries       fruit  09302   52.0    7.560665
# 24       2.471473         asparagus  vegetables  11011   20.0    6.502774

# %%
ticks = plt.xticks(rotation = 45)
ax = sns.barplot(x = "food", y = "value_lb", data = best_value_lb.head(10))
